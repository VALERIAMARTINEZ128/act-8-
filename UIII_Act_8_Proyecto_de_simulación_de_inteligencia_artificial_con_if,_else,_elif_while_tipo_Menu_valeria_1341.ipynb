# %% [markdown]
# <a href="https://colab.research.google.com/github/VALERIAMARTINEZ128/act-8-/blob/main/UIII_Act_8_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_con_if%2C_else%2C_elif_while_tipo_Menu_valeria_1341.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Valeria Yaretzi Lopez Martinez - 21 de mayo de 2026
# #### NL = 36

# %%
# ==========================================================
# 📚 SIMULADOR DE IA PARA ESTUDIANTES 📚
# Tema: Cuaderno Inteligente
# Nivel: Principiante
# Uso de if, elif, else y while
# ==========================================================

print("=================================================")
print("🤖 BIENVENIDO AL CUADERNO INTELIGENTE IA 📚")
print("Asistente virtual para estudiantes")
print("=================================================")

# Variable para mantener activo el programa
ejecutando = True

# Ciclo principal
while ejecutando == True:

    print("\n=========== MENÚ PRINCIPAL ===========")
    print("1. Revisar estado del cuaderno")
    print("2. Analizar tareas")
    print("3. Consejos de estudio")
    print("4. Salir")

    opcion = input("Selecciona una opción (1-4): ")

    # -------------------------------------------------
    # OPCIÓN 1
    # -------------------------------------------------
    if opcion == "1":

        print("\n📚 REVISIÓN DEL CUADERNO")

        estado = input("¿Tu cuaderno está 'ordenado', 'regular' o 'desordenado'?: ")

        if estado == "ordenado":
            print("✅ Excelente trabajo.")
            print("La IA detecta un cuaderno limpio y organizado.")
            print("Consejo: Sigue estudiando así.")

        elif estado == "regular":
            print("⚠️ Tu cuaderno necesita más orden.")
            print("Consejo IA: Usa colores y títulos.")

        elif estado == "desordenado":
            print("🚨 Atención.")
            print("Tu cuaderno puede afectar tu aprendizaje.")
            print("Consejo IA: Organiza tus apuntes urgentemente.")

        else:
            print("❌ Opción no válida.")

    # -------------------------------------------------
    # OPCIÓN 2
    # -------------------------------------------------
    elif opcion == "2":

        print("\n📝 ANÁLISIS DE TAREAS")

        tareas = input("¿Entregaste tus tareas? ('si' o 'no'): ")

        if tareas == "si":
            print("🎉 Muy bien.")
            print("La IA detecta responsabilidad académica.")
            print("Sigue así para mejorar tus calificaciones.")

        elif tareas == "no":
            print("⚠️ Advertencia.")
            print("Tienes tareas pendientes.")
            print("Consejo IA: Organiza mejor tu tiempo.")

        else:
            print("❌ Respuesta incorrecta.")

    # -------------------------------------------------
    # OPCIÓN 3
    # -------------------------------------------------
    elif opcion == "3":

        print("\n💡 CONSEJOS DE ESTUDIO")

        print("📖 Estudia mínimo 1 hora diaria.")
        print("🖍️ Usa colores para identificar temas.")
        print("⏰ Descansa 10 minutos después de estudiar.")
        print("📚 Mantén tu cuaderno limpio.")
        print("🎯 Entrega tus tareas a tiempo.")

    # -------------------------------------------------
    # OPCIÓN 4
    # -------------------------------------------------
    elif opcion == "4":

        print("\n👋 Cerrando Cuaderno Inteligente IA...")
        print("Gracias por usar el programa.")
        print("¡Hasta pronto estudiante!")

        ejecutando = False

    # -------------------------------------------------
    # OPCIÓN INCORRECTA
    # -------------------------------------------------
    else:

        print("\n❌ Opción inválida.")
        print("Selecciona un número del 1 al 4.")
# Out:
# ...
# 🤖 BIENVENIDO AL CUADERNO INTELIGENTE IA 📚
# Asistente virtual para estudiantes
# ...
#
# =========== MENÚ PRINCIPAL ===========
# 1. Revisar estado del cuaderno
# 2. Analizar tareas
# 3. Consejos de estudio
# 4. Salir
# Selecciona una opción (1-4): 1
#
# 📚 REVISIÓN DEL CUADERNO
# ¿Tu cuaderno está 'ordenado', 'regular' o 'desordenado'?: ordenado
# ✅ Excelente trabajo.
# La IA detecta un cuaderno limpio y organizado.
# Consejo: Sigue estudiando así.
#
# =========== MENÚ PRINCIPAL ===========
# 1. Revisar estado del cuaderno
# 2. Analizar tareas
# 3. Consejos de estudio
# 4. Salir
# Selecciona una opción (1-4): 4
#
# 👋 Cerrando Cuaderno Inteligente IA...
# Gracias por usar el programa.
# ¡Hasta pronto estudiante!

# %%
# ==========================================================
# 📚 SIMULADOR DE IA PARA ESTUDIANTES 📚
# Tema: Cuaderno Inteligente
# Nivel: Principiante
# Uso de if, elif, else y while
# ==========================================================

print("=================================================")
print("🤖 BIENVENIDO AL CUADERNO INTELIGENTE IA 📚")
print("Asistente virtual para estudiantes")
print("=================================================")

# Variable para mantener activo el programa
ejecutando = True

# Ciclo principal
while ejecutando == True:
    print("\n=========== MENÚ PRINCIPAL ===========")
    print("1. Revisar estado del cuaderno")
    print("2. Analizar tareas")
    print("3. Consejos de estudio")
    print("4. Salir")

    opcion = input("Selecciona una opción (1-4): ")
    # -------------------------------------------------
    # OPCIÓN 1
    # -------------------------------------------------
    if opcion == "1":
        print("\n📚 REVISIÓN DEL CUADERNO")
        estado = input("¿Tu cuaderno está 'ordenado', 'regular' o 'desordenado'?: ")
        if estado == "ordenado":
            print("✅ Excelente trabajo.")
            print("La IA detecta un cuaderno limpio y organizado.")
            print("Consejo: Sigue estudiando así.")
        elif estado == "regular":
            print("⚠️ Tu cuaderno necesita más orden.")
            print("Consejo IA: Usa colores y títulos.")

        elif estado == "desordenado":
            print("🚨 Atención.")
            print("Tu cuaderno puede afectar tu aprendizaje.")
            print("Consejo IA: Organiza tus apuntes urgentemente.")

        else:
            print("❌ Opción no válida.")
    # -------------------------------------------------
    # OPCIÓN 2
    # -------------------------------------------------
    elif opcion == "2":
        print("\n📝 ANÁLISIS DE TAREAS")
        tareas = input("¿Entregaste tus tareas? ('si' o 'no'): ")
        if tareas == "si":
            print("🎉 Muy bien.")
            print("La IA detecta responsabilidad académica.")
            print("Sigue así para mejorar tus calificaciones.")
        elif tareas == "no":
            print("⚠️ Advertencia.")
            print("Tienes tareas pendientes.")
            print("Consejo IA: Organiza mejor tu tiempo.")

        else:
            print("❌ Respuesta incorrecta.")

    # -------------------------------------------------
    # OPCIÓN 3
    # -------------------------------------------------
    elif opcion == "3":

        print("\n💡 CONSEJOS DE ESTUDIO")

        print("📖 Estudia mínimo 1 hora diaria.")
        print("🖍️ Usa colores para identificar temas.")
        print("⏰ Descansa 10 minutos después de estudiar.")
        print("📚 Mantén tu cuaderno limpio.")
        print("🎯 Entrega tus tareas a tiempo.")

    # -------------------------------------------------
    # OPCIÓN 4
    # -------------------------------------------------
    elif opcion == "4":

        print("\n👋 Cerrando Cuaderno Inteligente IA...")
        print("Gracias por usar el programa.")
        print("¡Hasta pronto estudiante!")

        ejecutando = False

    # -------------------------------------------------
    # OPCIÓN INCORRECTA
    # -------------------------------------------------
    else:

        print("\n❌ Opción inválida.")
        print("Selecciona un número del 1 al 4.")
# Out:
# ...
# 🤖 BIENVENIDO AL CUADERNO INTELIGENTE IA 📚
# Asistente virtual para estudiantes
# ...
#
# =========== MENÚ PRINCIPAL ===========
# 1. Revisar estado del cuaderno
# 2. Analizar tareas
# 3. Consejos de estudio
# 4. Salir
# Selecciona una opción (1-4): 2
#
# 📝 ANÁLISIS DE TAREAS
# ¿Entregaste tus tareas? ('si' o 'no'): si
# 🎉 Muy bien.
# La IA detecta responsabilidad académica.
# Sigue así para mejorar tus calificaciones.
#
# =========== MENÚ PRINCIPAL ===========
# 1. Revisar estado del cuaderno
# 2. Analizar tareas
# 3. Consejos de estudio
# 4. Salir
# Selecciona una opción (1-4): 4
#
# 👋 Cerrando Cuaderno Inteligente IA...
# Gracias por usar el programa.
# ¡Hasta pronto estudiante!

# %%
# ==========================================================
# 📚 SIMULADOR DE IA PARA ESTUDIANTES 📚
# Tema: Cuaderno Inteligente
# Nivel: Principiante
# Uso de if, elif, else y while
# ==========================================================

print("=================================================")
print("🤖 BIENVENIDO AL CUADERNO INTELIGENTE IA 📚")
print("Asistente virtual para estudiantes")
print("=================================================")

# Variable para mantener activo el programa
ejecutando = True

# Ciclo principal
while ejecutando == True:

    print("\n=========== MENÚ PRINCIPAL ===========")
    print("1. Revisar estado del cuaderno")
    print("2. Analizar tareas")
    print("3. Consejos de estudio")
    print("4. Salir")

    opcion = input("Selecciona una opción (1-4): ")

    # -------------------------------------------------
    # OPCIÓN 1
    # -------------------------------------------------
    if opcion == "1":

        print("\n📚 REVISIÓN DEL CUADERNO")

        estado = input("¿Tu cuaderno está 'ordenado', 'regular' o 'desordenado'?: ")

        if estado == "ordenado":
            print("✅ Excelente trabajo.")
            print("La IA detecta un cuaderno limpio y organizado.")
            print("Consejo: Sigue estudiando así.")

        elif estado == "regular":
            print("⚠️ Tu cuaderno necesita más orden.")
            print("Consejo IA: Usa colores y títulos.")

        elif estado == "desordenado":
            print("🚨 Atención.")
            print("Tu cuaderno puede afectar tu aprendizaje.")
            print("Consejo IA: Organiza tus apuntes urgentemente.")

        else:
            print("❌ Opción no válida.")

    # -------------------------------------------------
    # OPCIÓN 2
    # -------------------------------------------------
    elif opcion == "2":

        print("\n📝 ANÁLISIS DE TAREAS")

        tareas = input("¿Entregaste tus tareas? ('si' o 'no'): ")

        if tareas == "si":
            print("🎉 Muy bien.")
            print("La IA detecta responsabilidad académica.")
            print("Sigue así para mejorar tus calificaciones.")

        elif tareas == "no":
            print("⚠️ Advertencia.")
            print("Tienes tareas pendientes.")
            print("Consejo IA: Organiza mejor tu tiempo.")

        else:
            print("❌ Respuesta incorrecta.")

    # -------------------------------------------------
    # OPCIÓN 3
    # -------------------------------------------------
    elif opcion == "3":

        print("\n💡 CONSEJOS DE ESTUDIO")

        print("📖 Estudia mínimo 1 hora diaria.")
        print("🖍️ Usa colores para identificar temas.")
        print("⏰ Descansa 10 minutos después de estudiar.")
        print("📚 Mantén tu cuaderno limpio.")
        print("🎯 Entrega tus tareas a tiempo.")

    # -------------------------------------------------
    # OPCIÓN 4
    # -------------------------------------------------
    elif opcion == "4":

        print("\n👋 Cerrando Cuaderno Inteligente IA...")
        print("Gracias por usar el programa.")
        print("¡Hasta pronto estudiante!")

        ejecutando = False

    # -------------------------------------------------
    # OPCIÓN INCORRECTA
    # -------------------------------------------------
    else:

        print("\n❌ Opción inválida.")
        print("Selecciona un número del 1 al 4.")
# Out:
# ...
# 🤖 BIENVENIDO AL CUADERNO INTELIGENTE IA 📚
# Asistente virtual para estudiantes
# ...
#
# =========== MENÚ PRINCIPAL ===========
# 1. Revisar estado del cuaderno
# 2. Analizar tareas
# 3. Consejos de estudio
# 4. Salir
# Selecciona una opción (1-4): 3
#
# 💡 CONSEJOS DE ESTUDIO
# 📖 Estudia mínimo 1 hora diaria.
# 🖍️ Usa colores para identificar temas.
# ⏰ Descansa 10 minutos después de estudiar.
# 📚 Mantén tu cuaderno limpio.
# 🎯 Entrega tus tareas a tiempo.
#
# =========== MENÚ PRINCIPAL ===========
# 1. Revisar estado del cuaderno
# 2. Analizar tareas
# 3. Consejos de estudio
# 4. Salir
# Selecciona una opción (1-4): 4
#
# 👋 Cerrando Cuaderno Inteligente IA...
# Gracias por usar el programa.
# ¡Hasta pronto estudiante!

# %%
# ==========================================================
# 📚 SIMULADOR DE IA PARA ESTUDIANTES 📚
# Tema: Cuaderno Inteligente
# Nivel: Principiante
# Uso de if, elif, else y while
# ==========================================================

print("=================================================")
print("🤖 BIENVENIDO AL CUADERNO INTELIGENTE IA 📚")
print("Asistente virtual para estudiantes")
print("=================================================")

# Variable para mantener activo el programa
ejecutando = True

# Ciclo principal
while ejecutando:

    print("\n=========== MENÚ PRINCIPAL ===========")
    print("1. Revisar estado del cuaderno")
    print("2. Analizar tareas")
    print("3. Consejos de estudio")
    print("4. Salir")

    opcion = input("Selecciona una opción (1-4): ")

    # -------------------------------------------------
    # OPCIÓN 1
    # -------------------------------------------------
    if opcion == "1":

        print("\n📚 REVISIÓN DEL CUADERNO")

        estado = input("¿Tu cuaderno está 'ordenado', 'regular' o 'desordenado'?: ")

        if estado == "ordenado":
            print("✅ Excelente trabajo.")
            print("La IA detecta un cuaderno limpio y organizado.")
            print("Consejo: Sigue estudiando así.")

        elif estado == "regular":
            print("⚠️ Tu cuaderno necesita más orden.")
            print("Consejo IA: Usa colores y títulos.")

        elif estado == "desordenado":
            print("🚨 Atención.")
            print("Tu cuaderno puede afectar tu aprendizaje.")
            print("Consejo IA: Organiza tus apuntes urgentemente.")

        else:
            print("❌ Opción no válida.")

    # -------------------------------------------------
    # OPCIÓN 2
    # -------------------------------------------------
    elif opcion == "2":

        print("\n📝 ANÁLISIS DE TAREAS")

        tareas = input("¿Entregaste tus tareas? ('si' o 'no'): ")

        if tareas == "si":
            print("🎉 Muy bien.")
            print("La IA detecta responsabilidad académica.")
            print("Sigue así para mejorar tus calificaciones.")

        elif tareas == "no":
            print("⚠️ Advertencia.")
            print("Tienes tareas pendientes.")
            print("Consejo IA: Organiza mejor tu tiempo.")

        else:
            print("❌ Respuesta incorrecta.")

    # -------------------------------------------------
    # OPCIÓN 3
    # -------------------------------------------------
    elif opcion == "3":

        print("\n💡 CONSEJOS DE ESTUDIO")

        print("📖 Estudia mínimo 1 hora diaria.")
        print("🖍️ Usa colores para identificar temas.")
        print("⏰ Descansa 10 minutos después de estudiar.")
        print("📚 Mantén tu cuaderno limpio.")
        print("🎯 Entrega tus tareas a tiempo.")

    # -------------------------------------------------
    # OPCIÓN 4
    # -------------------------------------------------
    elif opcion == "4":

        print("\n👋 Cerrando Cuaderno Inteligente IA...")
        print("Gracias por usar el programa.")
        print("¡Hasta pronto estudiante!")

        ejecutando = False

    # -------------------------------------------------
    # OPCIÓN INCORRECTA
    # -------------------------------------------------
    else:

        print("\n❌ Opción inválida.")
        print("Selecciona un número del 1 al 4.")
# Out:
# ...
# 🤖 BIENVENIDO AL CUADERNO INTELIGENTE IA 📚
# Asistente virtual para estudiantes
# ...
#
# =========== MENÚ PRINCIPAL ===========
# 1. Revisar estado del cuaderno
# 2. Analizar tareas
# 3. Consejos de estudio
# 4. Salir
# Selecciona una opción (1-4): 4
#
# 👋 Cerrando Cuaderno Inteligente IA...
# Gracias por usar el programa.
# ¡Hasta pronto estudiante!

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/VALERIAMARTINEZ128/act-8-estudiante/refs/heads/main/ChatGPT%20Image%2021%20may%202026%2C%2007_09_57%20a.m..png)
